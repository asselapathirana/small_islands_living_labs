# %%
# open excel file land_pop_below_5m.xlsx and read into pandas
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# read the excel file
data = pd.read_excel('land_pop_below_5m.xlsx')
print (data.columns)
# Out:
# Index(['Country', 'Land below 5m (%)', 'Population below 5m (%)'], dtype='object')

# %%
# plot the data using seaborn x = land, y = pop
sns.scatterplot(x='Land below 5m (%)', y='Population below 5m (%)', data=df)
# log x and y axis
#plt.xscale('log')
#plt.yscale('log')
# mark 75% on each axis by lines
plt.axvline(x=75, color='r', linestyle='--')
plt.axhline(y=75, color='r', linestyle='--')
plt.show()
